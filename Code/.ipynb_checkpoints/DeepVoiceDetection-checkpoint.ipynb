# %%
"""we will import all data here and launch all functionality"""
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import tensorflow as tf
from keras import layers, models, optimizers
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn import preprocessing
# Out:
# 2024-03-03 13:18:42.887110: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Convert balanced csv into dataframe and seperate labels
DATASET_PATH = "/Users/connormaclachlan/Desktop/archive/KAGGLE/DATASET-balanced.csv"
df = pd.read_csv(DATASET_PATH)
data = df.iloc[:,:-1]
labels = df.iloc[:,-1]

# Binarize labels
lb = preprocessing.LabelBinarizer()
lb.fit(labels)
labels = lb.transform(labels)
labels = labels.ravel()

data
# Out:
#        chroma_stft       rms  spectral_centroid  spectral_bandwidth  \
# 0         0.338055  0.027948        2842.948867         4322.916759
# 1         0.443766  0.037838        2336.129597         3445.777044
# 2         0.302528  0.056578        2692.988386         2861.133180
# 3         0.319933  0.031504        2241.665382         3503.766175
# 4         0.420055  0.016158        2526.069123         3102.659519
# ...            ...       ...                ...                 ...
# 11773     0.435426  0.025303        2772.575031         2728.757601
# 11774     0.454611  0.070578        1029.274601         1519.231563
# 11775     0.374432  0.019063        4063.645317         3558.261357
# 11776     0.410885  0.090499        1124.655596         1553.651133
# 11777     0.570581  0.033022        2275.915286         3566.472303
#
#            rolloff  zero_crossing_rate       mfcc1       mfcc2      mfcc3  \
# 0      6570.586186            0.041050 -462.169586   90.311272  19.073769
# 1      3764.949874            0.047730 -409.413422  120.348808  -7.161531
# 2      4716.610271            0.080342 -318.996033  120.490273 -24.625771
# 3      3798.641521            0.047180 -404.636749  136.320908   2.308172
# 4      5025.077899            0.051905 -410.497925  152.731400 -18.266771
# ...            ...                 ...         ...         ...        ...
# 11773  4998.670213            0.074323 -342.309753  144.490418 -79.272942
# 11774  1922.927486            0.026553 -332.230408  202.603012  -0.181929
# 11775  7299.133512            0.110278 -372.149109   92.670235 -29.082432
# 11776  2065.942806            0.031761 -328.062805  193.557526   6.779151
# 11777  4054.590126            0.052983 -398.812103  129.081482   3.654665
#
#            mfcc4  ...     mfcc11     mfcc12    mfcc13    mfcc14    mfcc15  \
# 0      24.046888  ... -14.181895  -6.686564  0.902086 -7.251551 -1.198342
# 1       5.114784  ...   0.372541  -2.131157 -6.876417 -1.359395  0.326401
# 2      23.891073  ...  -3.099179  -5.853725 -3.724773 -6.627182 -5.117002
# 3      -3.907071  ...   1.513633  -1.898315 -2.046493 -7.176277 -3.293508
# 4      51.993462  ...  11.086248  -1.952340  0.810868  6.238493  6.555839
# ...          ...  ...        ...        ...       ...       ...       ...
# 11773   8.890874  ...  -2.950688 -17.982819 -7.831161 -1.127167 -7.669674
# 11774  -2.146542  ...  -2.910435  -2.018668 -2.705635 -1.589172 -2.938737
# 11775  59.736637  ... -17.552000  -6.628118 -3.827499 -7.287946 -2.899543
# 11776  -1.304731  ...  -7.348275  -5.437202 -4.252508 -1.258683 -2.107233
# 11777  18.412062  ...   4.769826   4.484940  3.916474  2.186594  1.218625
#
#           mfcc16    mfcc17     mfcc18    mfcc19     mfcc20
# 0       4.747403 -4.986279   0.953935 -5.013138  -6.779060
# 1      -5.420016 -2.109968  -1.757634 -9.537907  -8.494421
# 2      -6.072106 -0.994653  -1.617120 -3.922354  -7.033001
# 3       4.209121  0.121835  -5.407063 -3.654926  -3.274857
# 4       7.535542  2.849219   2.616843 -1.793357  -5.060998
# ...          ...       ...        ...       ...        ...
# 11773  -0.653850 -8.037575  -2.671002 -4.483765  -3.355975
# 11774  -0.972690 -1.706672  -2.796168  2.171270  -1.660128
# 11775 -11.508186 -1.296590 -14.325416 -4.405540 -15.869982
# 11776  -1.018154 -2.716950  -3.681598  3.811063   3.948419
# 11777   3.607651  4.629877   0.414103  5.229393   0.214607
#
# [11778 rows x 26 columns]

# %%
# Convert data into tensorflow dataset
def convertToDataset(data, labels):
    return tf.data.Dataset.zip(tf.data.Dataset.from_tensor_slices(data), tf.data.Dataset.from_tensor_slices(labels))

# Process dataset
def processData(data, labels):
    data = tf.abs(data)
    data = tf.expand_dims(data, axis=1)
    return data, labels

# %%
# Split data into training and testing and validation sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.3, random_state=42)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.10, random_state=42)

trainDataset = convertToDataset(X_train, y_train)
testDataset = convertToDataset(X_test, y_test)

# %%
trainDataset.as_numpy_iterator().next()
# Out:
# (array([ 4.98713000e-01,  4.40390000e-02,  3.25821094e+03,  3.85114700e+03,
#          6.83959255e+03,  8.13260000e-02, -3.67204224e+02,  1.34100235e+02,
#          4.87364100e+00,  2.30041580e+01,  1.04666810e+01,  5.70958000e-01,
#         -2.51008210e+01,  5.90441100e+00, -4.06430200e+00,  2.09046700e+00,
#         -6.00957800e+00,  6.85579500e+00, -7.11480500e+00, -1.39212100e+00,
#         -5.72690200e+00,  3.22187300e+00, -3.89038000e-01, -3.91204000e-01,
#         -1.62757600e+00,  4.55036000e-01]),
#  0)

# %%
X_train.shape
# Out:
# (8244, 26)

# %%
# Data processing
trainDataset = trainDataset.map(processData)
trainDataset = trainDataset.cache()
trainDataset = trainDataset.batch(64)
trainDataset = trainDataset.prefetch(32)

testDataset = testDataset.map(processData)
testDataset = testDataset.cache()
testDataset = testDataset.batch(64)
testDataset = testDataset.prefetch(32)

X_val = abs(X_val)

# %%
# Hyperparameters
opt = optimizers.Adam(learning_rate=0.001)
epochs = 100

# %%
# Define the NN model
model = models.Sequential([
    layers.Dense(128, activation='relu', input_shape=(26,)),
    layers.Dense(128, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(8, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer=opt, loss='BinaryCrossentropy', metrics=['accuracy'])

# Train the model
model.fit(trainDataset, epochs=epochs)

# Evaluate the model
test_loss, test_acc = model.evaluate(testDataset)

print(f"Test Accuracy: {test_acc}")
print(f"Test Loss: {test_loss}")
# Out:
# Epoch 1/100
# 129/129 [==============================] - 3s 4ms/step - loss: 8.0729 - accuracy: 0.6008
# Epoch 2/100
# 129/129 [==============================] - 0s 4ms/step - loss: 3.7093 - accuracy: 0.6661
# Epoch 3/100
# 129/129 [==============================] - 1s 6ms/step - loss: 2.9703 - accuracy: 0.6809
# Epoch 4/100
# 129/129 [==============================] - 0s 3ms/step - loss: 2.7279 - accuracy: 0.6898
# Epoch 5/100
# 129/129 [==============================] - 0s 4ms/step - loss: 1.5543 - accuracy: 0.7365
# Epoch 6/100
# 129/129 [==============================] - 0s 4ms/step - loss: 1.8400 - accuracy: 0.7106
# Epoch 7/100
# 129/129 [==============================] - 0s 2ms/step - loss: 1.6994 - accuracy: 0.7239
# Epoch 8/100
# 129/129 [==============================] - 0s 2ms/step - loss: 1.2475 - accuracy: 0.7541
# Epoch 9/100
# 129/129 [==============================] - 0s 2ms/step - loss: 1.6321 - accuracy: 0.7293
# Epoch 10/100
# 129/129 [==============================] - 0s 2ms/step - loss: 1.3777 - accuracy: 0.7468
# Epoch 11/100
# 129/129 [==============================] - 0s 3ms/step - loss: 1.0931 - accuracy: 0.7663
# Epoch 12/100
# 129/129 [==============================] - 0s 2ms/step - loss: 1.1414 - accuracy: 0.7604
# Epoch 13/100
# 129/129 [==============================] - 0s 2ms/step - loss: 1.7856 - accuracy: 0.7137
# Epoch 14/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.9139 - accuracy: 0.7848
# Epoch 15/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.8228 - accuracy: 0.7857
# Epoch 16/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.9540 - accuracy: 0.7669
# Epoch 17/100
# 129/129 [==============================] - 0s 2ms/step - loss: 1.2223 - accuracy: 0.7591
# Epoch 18/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.8561 - accuracy: 0.7834
# Epoch 19/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.7682 - accuracy: 0.7955
# Epoch 20/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.6068 - accuracy: 0.8149
# Epoch 21/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.7416 - accuracy: 0.7969
# Epoch 22/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.9651 - accuracy: 0.7762
# Epoch 23/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.6519 - accuracy: 0.8075
# Epoch 24/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.8694 - accuracy: 0.7817
# Epoch 25/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.7593 - accuracy: 0.7949
# Epoch 26/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.6842 - accuracy: 0.8029
# Epoch 27/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.6677 - accuracy: 0.8096
# Epoch 28/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.6072 - accuracy: 0.8173
# Epoch 29/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.5939 - accuracy: 0.8143
# Epoch 30/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.5926 - accuracy: 0.8160
# Epoch 31/100
# 129/129 [==============================] - 0s 3ms/step - loss: 0.5493 - accuracy: 0.8254
# Epoch 32/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.5225 - accuracy: 0.8315
# Epoch 33/100
# 129/129 [==============================] - 0s 3ms/step - loss: 0.5382 - accuracy: 0.8246
# Epoch 34/100
# 129/129 [==============================] - 0s 4ms/step - loss: 0.5081 - accuracy: 0.8295
# Epoch 35/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.4411 - accuracy: 0.8416
# Epoch 36/100
# 129/129 [==============================] - 0s 4ms/step - loss: 0.4681 - accuracy: 0.8418
# Epoch 37/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.4823 - accuracy: 0.8350
# Epoch 38/100
# 129/129 [==============================] - 1s 4ms/step - loss: 0.4720 - accuracy: 0.8389
# Epoch 39/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.4617 - accuracy: 0.8364
# Epoch 40/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.4493 - accuracy: 0.8464
# Epoch 41/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.4380 - accuracy: 0.8411
# Epoch 42/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.3718 - accuracy: 0.8570
# Epoch 43/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.3948 - accuracy: 0.8399
# Epoch 44/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.3385 - accuracy: 0.8552
# Epoch 45/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.3187 - accuracy: 0.8645
# Epoch 46/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.3184 - accuracy: 0.8638
# Epoch 47/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.3115 - accuracy: 0.8685
# Epoch 48/100
# 129/129 [==============================] - 0s 3ms/step - loss: 0.3179 - accuracy: 0.8657
# Epoch 49/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.3133 - accuracy: 0.8692
# Epoch 50/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.3036 - accuracy: 0.8735
# Epoch 51/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.3035 - accuracy: 0.8728
# Epoch 52/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.3037 - accuracy: 0.8741
# Epoch 53/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.3008 - accuracy: 0.8760
# Epoch 54/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.3017 - accuracy: 0.8753
# Epoch 55/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.3010 - accuracy: 0.8777
# Epoch 56/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.3017 - accuracy: 0.8763
# Epoch 57/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.3013 - accuracy: 0.8751
# Epoch 58/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2895 - accuracy: 0.8820
# Epoch 59/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2922 - accuracy: 0.8814
# Epoch 60/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.3011 - accuracy: 0.8771
# Epoch 61/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2970 - accuracy: 0.8787
# Epoch 62/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2813 - accuracy: 0.8846
# Epoch 63/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2771 - accuracy: 0.8845
# Epoch 64/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2745 - accuracy: 0.8863
# Epoch 65/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2738 - accuracy: 0.8879
# Epoch 66/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2656 - accuracy: 0.8899
# Epoch 67/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2618 - accuracy: 0.8901
# Epoch 68/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2583 - accuracy: 0.8935
# Epoch 69/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2690 - accuracy: 0.8882
# Epoch 70/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2567 - accuracy: 0.8922
# Epoch 71/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2563 - accuracy: 0.8948
# Epoch 72/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2521 - accuracy: 0.8953
# Epoch 73/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2515 - accuracy: 0.8953
# Epoch 74/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2508 - accuracy: 0.8964
# Epoch 75/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2468 - accuracy: 0.8973
# Epoch 76/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2449 - accuracy: 0.8985
# Epoch 77/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2416 - accuracy: 0.9016
# Epoch 78/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2348 - accuracy: 0.9033
# Epoch 79/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2310 - accuracy: 0.9042
# Epoch 80/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2321 - accuracy: 0.9044
# Epoch 81/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2311 - accuracy: 0.9041
# Epoch 82/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2313 - accuracy: 0.9051
# Epoch 83/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2282 - accuracy: 0.9074
# Epoch 84/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2193 - accuracy: 0.9088
# Epoch 85/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2221 - accuracy: 0.9066
# Epoch 86/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2263 - accuracy: 0.9079
# Epoch 87/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2305 - accuracy: 0.9065
# Epoch 88/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2185 - accuracy: 0.9093
# Epoch 89/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2171 - accuracy: 0.9104
# Epoch 90/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2124 - accuracy: 0.9129
# Epoch 91/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2065 - accuracy: 0.9159
# Epoch 92/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2066 - accuracy: 0.9168
# Epoch 93/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2031 - accuracy: 0.9176
# Epoch 94/100
# 129/129 [==============================] - 0s 3ms/step - loss: 0.1948 - accuracy: 0.9213
# Epoch 95/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.2081 - accuracy: 0.9182
# Epoch 96/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.1942 - accuracy: 0.9224
# Epoch 97/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.1957 - accuracy: 0.9238
# Epoch 98/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.1952 - accuracy: 0.9203
# Epoch 99/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.1892 - accuracy: 0.9247
# Epoch 100/100
# 129/129 [==============================] - 0s 2ms/step - loss: 0.1818 - accuracy: 0.9277
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2179 - accuracy: 0.9116
# Test Accuracy: 0.9116352200508118
# Test Loss: 0.21787619590759277

# %%
# Model given validation data to make prediction
predicted = model.predict(np.array(X_val))
predicted = tf.squeeze(predicted)
predicted = np.array([1 if x >= 0.5 else 0 for x in predicted])
actual = np.array(y_val)
conf_mat = confusion_matrix(actual, predicted)
displ = ConfusionMatrixDisplay(confusion_matrix=conf_mat)
displ.plot()
# Out:
# 12/12 [==============================] - 0s 1ms/step

# %%
# Validation percentage
predictPerc = (conf_mat[0][0]+conf_mat[1][1])/(conf_mat[0][0]+conf_mat[0][1]+conf_mat[1][0]+conf_mat[1][1])*100
print(f"Prediction Accuracy: {predictPerc}%")
# Out:
# Prediction Accuracy: 90.3954802259887%
